# %% [markdown]
# # Using SDSS-V Targeting Flags with `semaphore`
#
# ## Learning Goals
# By the end of this tutorial, you will:
# - How to select spectra by their targeting information
# - How to get the targeting information of a specific target
#
# ## Introduction
# The SDSS-V Survey uses a complex targeting schema, where targets are selected through many cartons associated with the different SDSS-V mappers and programs.
#
# In this short tutorial, we will briefly cover determining which targets in a summary file are associated with a particular carton, program, or master. It also describes how to determine the targeting information for a single source.
#
# ## Imports
#
# This tutorial requires two commonly used python packages and two SDSS specific packages
# - numpy for filtering of arrays
# - astropy for reading fits tables
# - sdss-access for accessing data on the SAS
# - semaphore for exploring the flags
#
# Missing packages can be installed via `pip install numpy astropy sdss-access sdss-semaphore==0.2.4`
#
#
# NOTE: You may want to set the `$SAS_BASE_DIR` environment variable before starting this notebook, other wise `$HOME/sas` will be created and used

# %%
import numpy as np
from astropy.io import fits
from sdss_access import Access
from sdss_semaphore.targeting import TargetingFlags

# setup sdss_access for DR19
access = Access(release='DR19')

# %% [markdown]
# ## Load the Data
# We will use `sdss-access` to find/download the file. `sdss-access` has extensive documentation, but we should mention a few things. First, if you are a member of the collaboration accessing proprietary data, you need to set up a .netrc file. After that usage is the same for everyone. For public data, no .netrc file is needed.
#
# You need specify the file species you need, in this case 'mwmAllVisit', then a series of keyword arguments that vary depending on the file species. A list of file species and their keyword arugments is available.
#
# The code below show an example of retreiving a summary file. access.full() builds the file path, access.exists() checks if the file exists, and access.commit() will retrieve the file and save it to your local SAS (`$SAS_BASE_DIR`) with the same structure as the SAS (so it will be many files deep).

# %%
filename = access.full('mwmAllVisit',v_astra = '0.6.0')
if not access.exists('',full=filename):
    # if the file does not exist locally, this code will download the data.
    access.remote()
    access.add('mwmAllVisit',v_astra = '0.6.0')
    access.set_stream()
    access.commit()
print(filename)
# Out:
# /uufs/chpc.utah.edu/common/home/sdss50/ipl-3/spectro/astra/0.6.0/summary/mwmAllVisit-0.6.0.fits.gz

# %% [markdown]
# ### Open the file
# Now use `astropy.fitsio` to load the data
# - HDU 1 contains the BOSS Spectra
# - HDU 2 contains the APOGEE Spectra

# %%
hdul = fits.open(filename)
hdul[0].header
boss_data = hdul[1].data

# %% [markdown]
# ### Converting the stored column to a set of Targeting Flags
# Now use the semaphore package to convert the fits column to Targeting Flags

# %%
flags = TargetingFlags(boss_data["SDSS5_TARGET_FLAGS"])

# %%
# Let's count the number of targets assigned to each carton (and skip empty cartons)
for label, count in flags.count(skip_empty=True).items():
    print(f"{label}: {count}")
# Out:
# mwm_snc_100pc_0.1.0: 38190
# mwm_snc_250pc_0.1.0: 2019
# mwm_cb_300pc_0.1.0: 123
# mwm_cb_cvcandidates_0.1.0: 971
# mwm_halo_sm_0.1.0: 2589
# mwm_halo_bb_0.1.0: 32694
# mwm_yso_s1_0.1.0: 13798
# mwm_yso_s2_0.1.0: 44
# mwm_yso_s2-5_0.1.0: 8
# mwm_yso_s3_0.1.0: 22710
# mwm_yso_ob_0.1.0: 16
# mwm_yso_cmz_0.1.0: 1
# mwm_yso_cluster_0.1.0: 20272
# mwm_rv_long-fps_0.1.0: 2597
# mwm_rv_long-bplates_0.1.0: 586
# mwm_ob_cepheids_0.1.0: 267
# mwm_rv_short-fps_0.1.0: 8429
# mwm_rv_short-bplates_0.1.0: 847
# mwm_ob_core_0.1.0: 147242
# mwm_rv_short-rm_0.1.0: 153
# mwm_rv_long-rm_0.1.0: 53
# ops_std_boss_0.1.0: 150693
# mwm_wd_core_0.1.0: 40413
# mwm_gg_core_0.1.0: 8571
# mwm_planet_tess_0.1.0: 5090
# bhm_aqmes_med_0.1.0: 1691
# mwm_cb_gaiagalex_0.1.0: 46436
# bhm_aqmes_med-faint_0.1.0: 3354
# mwm_tessrgb_core_0.1.0: 4772
# bhm_aqmes_wide3_0.1.0: 1718
# bhm_aqmes_wide3-faint_0.1.0: 2550
# bhm_aqmes_wide2_0.1.0: 1116
# bhm_aqmes_wide2-faint_0.1.0: 742
# bhm_aqmes_bonus-dark_0.1.0: 17438
# bhm_aqmes_bonus-bright_0.1.0: 1713
# bhm_csc_boss-dark_0.1.0: 40476
# bhm_csc_boss-bright_0.1.0: 3482
# bhm_csc_apogee_0.1.0: 353
# bhm_gua_dark_0.1.0: 10453
# bhm_gua_bright_0.1.0: 2816
# ops_std_eboss_0.1.0: 74574
# bhm_rm_core_0.1.0: 15604
# bhm_rm_known-spec_0.1.0: 29083
# bhm_rm_var_0.1.0: 5656
# bhm_rm_ancillary_0.1.0: 7101
# ops_std_boss-red_0.1.0: 28946
# bhm_spiders_agn-efeds_0.1.0: 807
# mwm_cb_uvex1_0.1.0: 21775
# mwm_cb_uvex2_0.1.0: 46574
# mwm_dust_core_0.1.0: 40
# mwm_cb_uvex3_0.1.0: 175
# mwm_cb_uvex4_0.1.0: 878
# mwm_cb_uvex5_0.1.0: 1209
# mwm_legacy_ir2opt_0.1.1: 24557
# ops_apogee_stds_0.1.2: 5070
# ops_std_boss_tic_0.1.3: 114001
# mwm_rv_long_bplates_0.1.4: 774
# ops_std_eboss_0.5.0: 74539
# ops_std_boss_0.5.0: 143485
# ops_std_boss_red_0.5.0: 28946
# ops_std_apogee_0.5.0: 5071
# mwm_cb_gaiagalex_apogee_0.5.0: 126
# mwm_cb_gaiagalex_boss_0.5.0: 46444
# mwm_cb_cvcandidates_apogee_0.5.0: 7
# mwm_cb_cvcandidates_boss_0.5.0: 971
# mwm_galactic_core_0.5.0: 8577
# mwm_cb_uvex3_0.5.0: 1138
# mwm_cb_uvex4_0.5.0: 1449
# mwm_snc_100pc_boss_0.5.0: 38210
# mwm_snc_250pc_apogee_0.5.0: 1988
# mwm_snc_250pc_boss_0.5.0: 2019
# mwm_halo_sm_boss_0.5.0: 2578
# mwm_yso_disk_apogee_0.5.0: 13798
# mwm_yso_disk_boss_0.5.0: 20938
# mwm_yso_embedded_apogee_0.5.0: 45
# mwm_yso_nebula_apogee_0.5.0: 8
# mwm_yso_variable_apogee_0.5.0: 22716
# mwm_yso_variable_boss_0.5.0: 22335
# mwm_yso_ob_apogee_0.5.0: 16
# mwm_yso_ob_boss_0.5.0: 16
# mwm_yso_cmz_apogee_0.5.0: 355
# mwm_yso_cluster_apogee_0.5.0: 20275
# mwm_yso_cluster_boss_0.5.0: 30538
# mwm_rv_short_fps_0.5.0: 8430
# mwm_legacy_ir2opt_0.5.0: 24567
# mwm_dust_core_0.5.0: 37
# mwm_wd_core_0.5.0: 40413
# mwm_tess_planet_0.5.0: 5552
# mwm_snc_100pc_apogee_0.5.0: 2125
# mwm_cb_uvex1_0.5.0: 21418
# mwm_cb_uvex2_0.5.0: 46484
# mwm_tessrgb_core_0.5.0: 4772
# ops_std_boss_tic_0.5.0: 114011
# mwm_rv_long_fps_0.5.0: 2597
# mwm_halo_bb_boss_0.5.0: 32271
# mwm_cb_300pc_apogee_0.5.0: 96
# mwm_cb_300pc_boss_0.5.0: 123
# bhm_spiders_agn_gaiadr2_0.5.0: 8754
# bhm_spiders_agn_lsdr8_0.5.0: 4060
# bhm_spiders_agn_sep_0.5.0: 11
# bhm_spiders_agn_efeds_stragglers_0.5.0: 735
# bhm_spiders_agn_ps1dr2_0.5.0: 6492
# bhm_spiders_agn_skymapperdr2_0.5.0: 3471
# bhm_spiders_agn_supercosmos_0.5.0: 3787
# bhm_spiders_clusters_ps1dr2_0.5.0: 15
# bhm_gua_bright_0.5.0: 5475
# bhm_gua_dark_0.5.0: 21009
# mwm_cb_uvex5_0.5.0: 1209
# bhm_rm_known_spec_0.5.0: 29650
# bhm_rm_core_0.5.0: 15860
# bhm_rm_var_0.5.0: 5544
# bhm_rm_ancillary_0.5.0: 7107
# ops_std_boss_lsdr8_0.5.0: 55655
# ops_std_boss_ps1dr2_0.5.0: 134931
# ops_std_boss_gdr2_0.5.0: 146949
# bhm_aqmes_med_0.5.0: 1793
# bhm_aqmes_med_faint_0.5.0: 3826
# bhm_csc_boss_dark_0.5.0: 42540
# bhm_csc_boss_bright_0.5.0: 3669
# bhm_csc_apogee_0.5.0: 495
# mwm_yso_pms_apogee_0.5.1: 21704
# mwm_yso_pms_boss_0.5.1: 22908
# mwm_ob_core_0.5.1: 147469
# mwm_ob_cepheids_0.5.1: 268
# mwm_halo_bb_boss_0.5.1: 32344
# mwm_halo_sm_boss_0.5.1: 2589
# mwm_erosita_stars_0.5.2: 6562
# mwm_erosita_compact_gen_0.5.2: 2332
# mwm_erosita_compact_var_0.5.2: 1229
# openfibertargets_nov2020_25_0.5.2-test: 27444
# openfibertargets_nov2020_28a_0.5.2-test: 3069
# openfibertargets_nov2020_28b_0.5.2-test: 3862
# openfibertargets_nov2020_28c_0.5.2-test: 3227
# openfibertargets_nov2020_35a_0.5.2-test: 14047
# openfibertargets_nov2020_35b_0.5.2-test: 961
# openfibertargets_nov2020_5_0.5.2-test: 1379
# openfibertargets_nov2020_6b_0.5.2-test: 8291
# openfibertargets_nov2020_6c_0.5.2-test: 35125
# openfibertargets_nov2020_10_0.5.3: 60
# openfibertargets_nov2020_1000_0.5.3: 119
# openfibertargets_nov2020_1001a_0.5.3: 3153
# openfibertargets_nov2020_1001b_0.5.3: 196
# openfibertargets_nov2020_11_0.5.3: 3508
# openfibertargets_nov2020_12_0.5.3: 2373
# openfibertargets_nov2020_14_0.5.3: 877
# openfibertargets_nov2020_15_0.5.3: 5780
# openfibertargets_nov2020_17_0.5.3: 6442
# openfibertargets_nov2020_18_0.5.3: 2399
# openfibertargets_nov2020_22_0.5.3: 271
# openfibertargets_nov2020_24_0.5.3: 31217
# openfibertargets_nov2020_25_0.5.3: 27444
# openfibertargets_nov2020_26_0.5.3: 193
# openfibertargets_nov2020_27_0.5.3: 19630
# openfibertargets_nov2020_28a_0.5.3: 3069
# openfibertargets_nov2020_28b_0.5.3: 3862
# openfibertargets_nov2020_28c_0.5.3: 3227
# openfibertargets_nov2020_29_0.5.3: 549
# openfibertargets_nov2020_3_0.5.3: 817
# openfibertargets_nov2020_30_0.5.3: 6
# openfibertargets_nov2020_31_0.5.3: 16
# openfibertargets_nov2020_32_0.5.3: 3346
# openfibertargets_nov2020_33_0.5.3: 610
# openfibertargets_nov2020_35a_0.5.3: 14047
# openfibertargets_nov2020_35b_0.5.3: 961
# openfibertargets_nov2020_35c_0.5.3: 1172
# openfibertargets_nov2020_46_0.5.3: 29517
# openfibertargets_nov2020_47a_0.5.3: 1633
# openfibertargets_nov2020_47b_0.5.3: 50
# openfibertargets_nov2020_47c_0.5.3: 1
# openfibertargets_nov2020_47d_0.5.3: 1
# openfibertargets_nov2020_8_0.5.3: 16424
# openfibertargets_nov2020_9_0.5.3: 9526
# openfibertargets_nov2020_19a_0.5.3: 8004
# openfibertargets_nov2020_19b_0.5.3: 18
# openfibertargets_nov2020_19c_0.5.3: 46
# manual_nsbh_apogee_0.5.3: 21
# manual_nsbh_boss_0.5.3: 59
# manual_bhm_spiders_comm_0.5.3: 544
# bhm_aqmes_bonus_bright_0.5.4: 1858
# bhm_aqmes_bonus_core_0.5.4: 8606
# bhm_aqmes_bonus_faint_0.5.4: 21022
# bhm_aqmes_wide2_0.5.4: 2884
# bhm_aqmes_wide2_faint_0.5.4: 3885
# mwm_cb_300pc_boss_0.5.4: 19836
# openfibertargets_nov2020_5_0.5.3: 1379
# openfibertargets_nov2020_6a_0.5.3: 1396
# openfibertargets_nov2020_6b_0.5.3: 8439
# openfibertargets_nov2020_6c_0.5.3: 35719
# manual_bright_target_offsets_1_0.5.3: 1896
# manual_bright_target_offsets_1_g13_0.5.3: 1451
# manual_bright_targets_g13_0.5.3: 1451
# manual_bright_targets_g13_offset_fixed_1_0.5.3: 1451
# manual_bright_targets_g13_offset_fixed_3_0.5.3: 1451
# manual_bright_targets_g13_offset_fixed_5_0.5.3: 1451
# manual_bright_targets_g13_offset_fixed_7_0.5.3: 1451
# manual_fps_position_stars_0.5.3: 13591
# manual_fps_position_stars_10_0.5.3: 54125
# openfibertargets_nov2020_34a_0.5.13: 250825
# openfibertargets_nov2020_34b_0.5.13: 17821
# bhm_csc_boss_0.5.14: 50192
# bhm_csc_boss_0.5.15: 49911
# bhm_csc_apogee_0.5.15: 2941
# bhm_colr_galaxies_lsdr8_0.5.16: 2553
# mwm_yso_cluster_apogee_0.5.17: 20275
# mwm_yso_cluster_boss_0.5.17: 30538
# mwm_yso_cmz_apogee_0.5.17: 355
# mwm_yso_disk_apogee_0.5.17: 13798
# mwm_yso_disk_boss_0.5.17: 20938
# mwm_yso_embedded_apogee_0.5.17: 45
# mwm_yso_nebula_apogee_0.5.17: 8
# mwm_yso_variable_apogee_0.5.17: 22716
# mwm_yso_variable_boss_0.5.17: 22335
# mwm_rv_long_fps_0.5.18: 2597
# mwm_rv_short_fps_0.5.18: 8430
# mwm_cb_300pc_apogee_0.5.19: 72
# mwm_cb_300pc_boss_0.5.19: 7762
# manual_fps_position_stars_apogee_10_0.5.13: 54125
# manual_offset_mwmhalo_off00_0.5.13: 148
# manual_offset_mwmhalo_off05_0.5.13: 148
# manual_offset_mwmhalo_off10_0.5.13: 148
# manual_offset_mwmhalo_off20_0.5.13: 148
# manual_offset_mwmhalo_off30_0.5.13: 148
# manual_offset_mwmhalo_offa_0.5.13: 148
# manual_offset_mwmhalo_offb_0.5.13: 148
# manual_bright_target_offsets_3_0.5.20: 1896
# ops_std_apogee_0.5.22: 6418
# manual_bhm_spiders_comm_lco_0.5.23: 2439
# manual_fps_position_stars_lco_apogee_10_0.5.23: 8
# bhm_spiders_agn_sep_1.0.5: 79
# ops_std_boss_lsdr10_1.0.5: 56695
# mwm_yso_cluster_apogee_1.0.6: 20275
# mwm_yso_cluster_boss_1.0.6: 30538
# mwm_yso_disk_apogee_1.0.6: 12579
# mwm_yso_disk_boss_1.0.6: 19488
# mwm_yso_cmz_apogee_1.0.6: 320
# mwm_yso_variable_apogee_1.0.6: 11853
# mwm_yso_variable_boss_1.0.6: 11678
# mwm_yso_embedded_apogee_1.0.6: 45
# mwm_yso_pms_apogee_zari18pms_1.0.6: 7739
# mwm_yso_pms_boss_sagitta_edr3_1.0.6: 17227
# mwm_yso_pms_boss_zari18pms_1.0.6: 7808
# openfibertargets_nov2020_11_1.0.7: 3508
# openfibertargets_nov2020_18_1.0.7: 2399
# openfibertargets_nov2020_26_1.0.7: 193
# openfibertargets_nov2020_27_1.0.7: 19630
# openfibertargets_nov2020_30_1.0.7: 6
# mwm_yso_nebula_apogee_1.0.8: 8
# manual_mwm_halo_distant_kgiant_1.0.7: 3521
# manual_mwm_halo_mp_bbb_1.0.7: 1718
# openfibertargets_nov2020_10_1.0.7: 60
# openfibertargets_nov2020_1000_1.0.7: 119
# openfibertargets_nov2020_12_1.0.7: 2373
# openfibertargets_nov2020_14_1.0.7: 877
# openfibertargets_nov2020_15_1.0.7: 5780
# openfibertargets_nov2020_22_1.0.7: 271
# openfibertargets_nov2020_24_1.0.7: 31217
# openfibertargets_nov2020_29_1.0.7: 549
# openfibertargets_nov2020_3_1.0.7: 817
# openfibertargets_nov2020_31_1.0.7: 16
# openfibertargets_nov2020_34a_1.0.7: 250832
# openfibertargets_nov2020_34b_1.0.7: 17821
# openfibertargets_nov2020_35b_1.0.7: 961
# openfibertargets_nov2020_35c_1.0.7: 1172
# openfibertargets_nov2020_46_1.0.7: 29517
# openfibertargets_nov2020_5_1.0.7: 1379
# openfibertargets_nov2020_6a_1.0.7: 1396
# openfibertargets_nov2020_6b_1.0.7: 8439
# openfibertargets_nov2020_6c_1.0.7: 35719
# openfibertargets_nov2020_8_1.0.7: 16424
# openfibertargets_nov2020_9_1.0.7: 9526
# openfibertargets_nov2020_28a_1.0.7: 3069
# openfibertargets_nov2020_33_1.0.10: 610
# bhm_rm_core_1.0.12: 15772
# bhm_rm_known_spec_1.0.12: 29770
# bhm_rm_var_1.0.12: 5544
# bhm_rm_ancillary_1.0.12: 7111
# bhm_rm_xrayqso_1.0.12: 8
# manual_mwm_magcloud_massive_apogee_1.0.10: 1
# manual_mwm_magcloud_massive_boss_1.0.10: 1
# ops_std_boss_gdr2_1.0.13: 146949
# ops_std_apogee_1.0.14: 6419
# ops_std_eboss_1.0.15: 74499
# ops_std_boss_1.0.16: 143485
# ops_std_boss_red_1.0.16: 28946
# ops_std_boss_tic_1.0.16: 110241
# mwm_snc_100pc_apogee_1.0.17: 2280
# mwm_snc_100pc_boss_1.0.17: 34056
# mwm_bin_gaia_astb_apogee_1.0.19: 253
# mwm_bin_gaia_astb_boss_1.0.19: 1507
# mwm_bin_gaia_sb_apogee_1.0.19: 99
# mwm_bin_gaia_sb_boss_1.0.19: 407
# mwm_yso_pms_apogee_sagitta_edr3_1.0.20: 16757
# mwm_snc_100pc_boss_1.0.24: 34056
# mwm_snc_100pc_boss_1.0.28: 34056
# mwm_yso_disk_apogee_single_1.0.33: 12579
# mwm_yso_disk_boss_single_1.0.33: 19488
# mwm_yso_embedded_apogee_single_1.0.33: 45
# mwm_yso_nebula_apogee_single_1.0.33: 8
# mwm_yso_variable_apogee_single_1.0.33: 11853
# mwm_yso_variable_boss_single_1.0.33: 11678
# mwm_yso_cmz_apogee_single_1.0.33: 320
# mwm_yso_cluster_apogee_single_1.0.33: 20275
# mwm_yso_cluster_boss_single_1.0.33: 30538
# mwm_yso_pms_apogee_sagitta_edr3_single_1.0.33: 16757
# mwm_yso_pms_apogee_zari18pms_single_1.0.33: 7739
# mwm_yso_pms_boss_sagitta_edr3_single_1.0.33: 17227
# mwm_yso_pms_boss_zari18pms_single_1.0.33: 7808
# ops_std_boss_ps1dr2_1.0.29: 134916
# bhm_csc_boss_1.0.37: 36409
# bhm_csc_apogee_1.0.37: 3115
# bhm_gua_dark_1.0.37: 32905
# bhm_gua_bright_1.0.37: 7752
# bhm_spiders_clusters_lsdr10_1.0.37: 11
# bhm_spiders_agn_lsdr10_1.0.37: 10610
# bhm_spiders_agn_hard_1.0.37: 42
# bhm_spiders_agn_gaiadr3_1.0.37: 15130
# bhm_spiders_agn_tda_1.0.37: 158
# bhm_spiders_agn_sep_1.0.37: 79
# bhm_aqmes_med_1.0.37: 1786
# bhm_aqmes_med_faint_1.0.37: 3824
# bhm_aqmes_wide2_1.0.37: 2885
# bhm_aqmes_wide2_faint_1.0.37: 3885
# bhm_aqmes_bonus_core_1.0.37: 8601
# bhm_aqmes_bonus_bright_1.0.37: 1852
# bhm_aqmes_bonus_faint_1.0.37: 21020
# manual_mwm_crosscalib_apogee_1.0.35: 20
# manual_mwm_crosscalib_yso_apogee_1.0.35: 544
# manual_mwm_crosscalib_yso_boss_1.0.35: 544
# manual_mwm_halo_distant_bhb_boss_1.0.35: 3847
# manual_mwm_halo_distant_bhb_boss_single_1.0.35: 3847
# manual_mwm_halo_distant_kgiant_far_boss_1.0.35: 1387
# manual_mwm_halo_distant_kgiant_far_boss_single_1.0.35: 1387
# manual_mwm_halo_distant_kgiant_near_boss_1.0.35: 2134
# manual_mwm_halo_distant_kgiant_near_boss_single_1.0.35: 2134
# manual_mwm_halo_mp_wise_apogee_1.0.35: 60
# manual_mwm_halo_mp_wise_apogee_single_1.0.35: 60
# manual_mwm_halo_mp_wise_boss_1.0.35: 1016
# manual_mwm_halo_mp_wise_boss_single_1.0.35: 1016
# manual_mwm_halo_vmp_wise_apogee_1.0.35: 46
# manual_mwm_halo_vmp_wise_apogee_single_1.0.35: 46
# manual_mwm_halo_vmp_wise_boss_1.0.35: 596
# manual_mwm_halo_vmp_wise_boss_single_1.0.35: 596
# bhm_colr_galaxies_lsdr10_1.0.38: 1979
# manual_mwm_validation_cool_apogee_1.0.35: 34
# manual_mwm_validation_cool_boss_1.0.35: 1954
# manual_mwm_validation_hot_boss_1.0.35: 13
# mwm_ob_core_boss_1.0.39: 17783
# mwm_ob_core_boss_single_1.0.39: 17783
# mwm_ob_cepheids_boss_1.0.39: 268
# mwm_bin_rv_long_apogee_1.0.39: 513
# mwm_bin_rv_short_mdwarf_apogee_18epoch_1.0.39: 9452
# mwm_bin_rv_short_mdwarf_apogee_12epoch_1.0.39: 9452
# mwm_bin_rv_short_mdwarf_apogee_08epoch_1.0.39: 9452
# mwm_bin_rv_short_subgiant_apogee_1.0.39: 2418
# mwm_bin_rv_short_rgb_apogee_1.0.39: 1485
# mwm_halo_distant_rrl_boss_single_1.0.39: 3236
# mwm_halo_distant_rrl_boss_1.0.39: 3236
# mwm_halo_vmp_xp_boss_single_1.0.39: 1131
# mwm_halo_nmp_xp_boss_single_1.0.39: 4696
# mwm_halo_vmp_xp_apogee_single_1.0.39: 23
# mwm_halo_mp_xp_apogee_single_1.0.39: 88
# mwm_halo_nmp_xp_apogee_single_1.0.39: 132
# mwm_halo_vmp_xp_boss_1.0.39: 1131
# mwm_halo_mp_xp_boss_1.0.39: 2617
# mwm_halo_nmp_xp_boss_1.0.39: 4696
# mwm_halo_vmp_xp_apogee_1.0.39: 23
# mwm_halo_mp_xp_apogee_1.0.39: 88
# mwm_halo_nmp_xp_apogee_1.0.39: 132
# mwm_halo_local_high_apogee_single_1.0.39: 166
# mwm_halo_local_high_boss_single_1.0.39: 30940
# mwm_halo_local_low_boss_single_1.0.39: 4050
# mwm_halo_local_high_apogee_1.0.39: 166
# mwm_halo_local_high_boss_1.0.39: 30940
# mwm_halo_local_low_boss_1.0.39: 4050
# mwm_erosita_stars_boss_1.0.40: 11000
# mwm_erosita_compact_boss_1.0.40: 431
# mwm_erosita_compact_boss_shallow_1.0.40: 431
# mwm_halo_mp_xp_boss_single_1.0.41: 2617
# mwm_snc_ext_main_apogee_1.0.41: 483
# mwm_snc_ext_filler_apogee_1.0.41: 7120
# mwm_snc_ext_main_boss_1.0.41: 5578
# mwm_snc_ext_filler_boss_1.0.41: 105735
# mwm_monitor_n188_apogee_long_1.0.42: 5
# mwm_monitor_m67_apogee_short_1.0.42: 17
# mwm_wd_pwd_boss_1.0.42: 40457
# mwm_wd_gaia_boss_1.0.42: 37270
# mwm_cb_galex_mag_boss_1.0.42: 28762
# mwm_cb_galex_vol_boss_1.0.42: 41684
# mwm_cb_xmmom_boss_1.0.42: 678
# mwm_cb_swiftuvot_boss_1.0.42: 604
# mwm_astar_core_boss_1.0.43: 70094
# mwm_astar_core_boss_single_1.0.43: 70094
# mwm_bin_vis_apogee_1.0.44: 919
# mwm_bin_vis_boss_1.0.44: 19646
# mwm_galactic_core_dist_apogee_1.0.44: 5859
# mwm_dust_core_dist_apogee_1.0.45: 42
# manual_mwm_nsbh_apogee_1.0.46: 21
# manual_mwm_nsbh_boss_1.0.46: 59
# mwm_cb_cvcandidates_apogee_1.0.47: 7
# mwm_cb_cvcandidates_boss_1.0.47: 971
# mwm_legacy_ir2opt_boss_1.0.47: 27669
# bhm_rm_core_1.0.48: 15721
# bhm_rm_known_spec_1.0.48: 29759
# bhm_rm_var_1.0.48: 5544
# bhm_rm_ancillary_1.0.48: 7111
# mwm_tess_2min_apogee_1.0.49: 7238
# mwm_tess_rgb_apogee_1.0.49: 8516
# manual_mwm_planet_gaia_astrometry_apogee_1.0.46: 5001
# manual_mwm_planet_known_apogee_1.0.46: 11
# manual_mwm_planet_tess_eb_apogee_1.0.46: 112
# manual_mwm_planet_tess_pc_apogee_1.0.46: 74
# mwm_magcloud_agb_apogee_1.0.50: 51
# mwm_magcloud_rgb_boss_1.0.50: 1554

# %% [markdown]
# # Flags have attributes
#
# The counts above are for targets assigned to a specific carton, with a specific version. Sometimes we don't care about the carton version and we just want to count by the effective number of targets assigned to that carton (over all versions), or we might want to count by the number of targets assigned to each mapper, or some other attribute.
#
# The `TargetingFlags.mapping` attribute contains a reference dictionary for all cartons, including their attributes. Here's how we can count targets by those attributes:

# %%
for mapper, count in flags.count_by_attribute("mapper").items():
    print(f"{mapper}: {count:,}")
# Out:
# mwm: 577,505
# ops: 396,005
# bhm: 73,516
# open: 450,749

# %%
for program, count in flags.count_by_attribute("program").items():
    print(f"{program}: {count:,}")
# Out:
# mwm_snc: 149,314
# mwm_cb: 91,007
# mwm_halo: 85,511
# mwm_yso: 86,540
# mwm_rv: 11,548
# mwm_ob: 148,043
# ops_std: 351,759
# mwm_wd: 42,128
# mwm_gg: 8,571
# mwm_planet: 11,137
# bhm_aqmes: 4,346
# bhm_filler: 43,243
# mwm_tessrgb: 8,521
# bhm_csc: 55,637
# ops_sky: 0
# bhm_rm: 31,079
# bhm_spiders: 18,851
# mwm_dust: 82
# mwm_legacy: 28,031
# mwm_galactic: 9,746
# mwm_filler: 54,536
# mwm_tess_ob: 0
# mwm_erosita: 16,380
# open_fiber: 450,749
# commissioning: 59,120
# SKY: 0
# mwm_tessob: 0
# mwm_magcloud: 1,558
# mwm_bin: 15,571
# mwm_validation: 2,553
# mwm_monitor: 22

# %% [markdown]
# # I own a carton. Where are my spectra?
#
# You can efficiently construct boolean masks to select spectra that are assigned to a carton, program, mapper, or any other attribute.
#
# The easiest way to do this is with the following methods:
# - `TargetingFlags.in_carton_pk`: If you know the database primary key (`targetdb.carton.pk`) of your carton
# - `TargetingFlags.in_carton_name`: If you know the name of your carton.
# - `TargetingFlags.in_carton_label`: If you know the name and version (name_ver) of your carton
# - `TargetingFlags.in_mapper`: To select by mapper (e.g., BHM, MWM)
# - `TargetingFlags.in_program`: To select by program name.
# - `TargetingFlags.in_alt_name`: To select by alternative name, curated with thanks by Marina Koukel.
# - `TargetingFlags.in_alt_program`: To select by alternative program name, curated with thanks by Marina Koukel.
#
# If you're not sure what your carton's alternative name or program is, you might find these properties useful:
#
# - `TargetingFlags.all_mappers`: a tuple of all unique mapper names;
# - `TargetingFlags.all_programs`: a tuple of all unique program names;
# - `TargetingFlags.all_carton_names`: a tuple of all unique carton names;
# - `TargetingFlags.all_alt_carton_names`: a tuple of all unique alternative names;
# - `TargetingFlags.all_alt_programs`: a tuple of all unique alternative program names;
#
# or you can look this up from `TargetingFlags.mapping`.

# %%
print("Mappers:")
for mapper in flags.all_mappers:
    print(f"\t{mapper}")
    
print("Programs")
for program in flags.all_programs:
    print(f"\t{program}")

print("Cartons names")
for name in flags.all_carton_names:
    print(f"\t{name}")

print("Alternative cartons names")
for alt_name in flags.all_alt_carton_names:
    print(f"\t{alt_name}")

print("Alternative programs")
for alt_program in flags.all_alt_programs:
    print(f"\t{alt_program}")
# Out:
# Mappers:
# 	ops
# 	bhm
# 	open
# 	mwm
# Programs
# 	ops_std
# 	mwm_wd
# 	mwm_galactic
# 	mwm_monitor
# 	mwm_filler
# 	mwm_cb
# 	open_fiber
# 	mwm_planet
# 	mwm_dust
# 	mwm_tessrgb
# 	bhm_csc
# 	mwm_legacy
# 	bhm_aqmes
# 	mwm_validation
# 	mwm_yso
# 	mwm_tess_ob
# 	bhm_filler
# 	bhm_rm
# 	mwm_magcloud
# 	mwm_halo
# 	mwm_snc
# 	mwm_erosita
# 	SKY
# 	commissioning
# 	mwm_tessob
# 	ops_sky
# 	bhm_spiders
# 	mwm_ob
# 	mwm_bin
# 	mwm_gg
# 	mwm_rv
# Cartons names
# 	bhm_colr_galaxies_lsdr10
# 	mwm_halo_nmp_xp_apogee
# 	mwm_yso_disk_boss_single
# 	manual_fps_position_stars
# 	mwm_rv_long-fps
# 	mwm_cb_galex_mag_boss
# 	mwm_yso_variable_boss
# 	manual_mwm_halo_vmp_wise_apogee
# 	mwm_halo_nmp_xp_boss_single
# 	mwm_halo_local_high_apogee
# 	mwm_halo_nmp_xp_boss
# 	bhm_spiders_agn_skymapperdr2
# 	manual_bright_targets_g13_offset_fixed_3
# 	mwm_halo_local_low_apogee
# 	openfibertargets_nov2020_6c
# 	manual_mwm_halo_mp_wise_apogee_single
# 	bhm_colr_galaxies_lsdr8
# 	ops_std_boss_red
# 	mwm_yso_ob
# 	mwm_erosita_stars_boss
# 	manual_mwm_planet_transiting_bd_apogee
# 	openfibertargets_nov2020_9
# 	mwm_halo_local_low_boss
# 	bhm_csc_boss_dark
# 	bhm_spiders_agn_supercosmos
# 	openfibertargets_nov2020_35b
# 	manual_mwm_planet_tess_eb_apogee
# 	mwm_cb_gaiagalex_boss
# 	mwm_cb_cvcandidates
# 	ops_sky_boss_fallback
# 	mwm_yso_pms_boss_sagitta_edr3
# 	mwm_snc_100pc
# 	manual_mwm_halo_mp_wise_boss
# 	openfibertargets_nov2020_6b
# 	mwm_magcloud_agb_apogee
# 	mwm_galactic_core_dist_apogee
# 	mwm_snc_ext_filler_apogee
# 	openfibertargets_nov2020_34b
# 	ops_apogee_stds
# 	mwm_yso_ob_apogee
# 	bhm_spiders_agn_sep
# 	mwm_yso_ob_boss
# 	mwm_bin_gaia_astb_boss
# 	mwm_rv_short-bplates
# 	bhm_spiders_agn_tda
# 	mwm_yso_pms_boss_sagitta_edr3_single
# 	manual_mwm_halo_distant_bhb_boss_single
# 	mwm_monitor_m15_apogee_long
# 	manual_mwm_halo_distant_kgiant_near_boss_single
# 	mwm_planet_tess
# 	mwm_rv_long_bplates
# 	mwm_halo_mp_xp_boss_single
# 	mwm_monitor_n188_apogee_long
# 	manual_mwm_magcloud_massive_apogee
# 	bhm_gua_bright
# 	manual_bright_targets_g13_offset_fixed_5
# 	mwm_tess_planet
# 	bhm_spiders_agn_lsdr10
# 	mwm_halo_local_high_boss
# 	mwm_erosita_compact_var
# 	mwm_yso_pms_apogee_zari18pms
# 	mwm_snc_ext_filler_boss
# 	mwm_yso_nebula_apogee
# 	mwm_halo_vmp_xp_apogee_single
# 	mwm_snc_250pc
# 	bhm_gua_dark
# 	openfibertargets_nov2020_47b
# 	mwm_yso_cluster_boss
# 	mwm_halo_vmp_xp_boss_single
# 	mwm_yso_embedded_apogee
# 	bhm_csc_boss-dark
# 	manual_nsbh_apogee
# 	mwm_halo_sm_boss
# 	mwm_yso_cluster_apogee
# 	mwm_galactic_core
# 	mwm_halo_mp_xp_boss
# 	openfibertargets_nov2020_10
# 	manual_bhm_spiders_comm
# 	manual_bright_targets_g13_offset_fixed_1
# 	mwm_cb_swiftuvot_boss
# 	openfibertargets_nov2020_47c
# 	openfibertargets_nov2020_19b
# 	mwm_bin_rv_short_rgb_apogee
# 	openfibertargets_nov2020_26
# 	manual_mwm_nsbh_apogee
# 	openfibertargets_nov2020_35c
# 	bhm_aqmes_bonus_bright
# 	bhm_csc_boss_bright
# 	manual_mwm_crosscalib_yso_boss
# 	manual_mwm_halo_vmp_wise_apogee_single
# 	manual_mwm_halo_distant_kgiant_far_boss
# 	mwm_yso_disk_apogee_single
# 	bhm_spiders_clusters-efeds-erosita
# 	manual_mwm_validation_cool_apogee
# 	mwm_halo_local_low_apogee_single
# 	mwm_cb_300pc_apogee
# 	manual_offset_mwmhalo_off05
# 	manual_mwm_halo_vmp_wise_boss
# 	openfibertargets_nov2020_35a
# 	mwm_snc_100pc_boss
# 	mwm_wd_gaia_boss
# 	mwm_yso_cluster
# 	manual_bright_targets_g13
# 	mwm_bin_vis_boss
# 	manual_mwm_halo_distant_kgiant_far_boss_single
# 	mwm_gg_core
# 	mwm_bin_vis_apogee
# 	openfibertargets_nov2020_25
# 	mwm_ob_core
# 	mwm_yso_cmz_apogee_single
# 	bhm_aqmes_wide2-faint
# 	openfibertargets_nov2020_28b
# 	openfibertargets_nov2020_28a
# 	openfibertargets_nov2020_18
# 	mwm_yso_disk_boss
# 	ops_std_boss-red
# 	bhm_aqmes_bonus_faint
# 	mwm_rv_long-rm
# 	mwm_yso_pms_boss_zari18pms
# 	bhm_spiders_clusters_lsdr10
# 	mwm_yso_s2
# 	mwm_wd_pwd_boss
# 	mwm_rv_long-bplates
# 	mwm_halo_vmp_xp_apogee
# 	manual_mwm_validation_hot_boss
# 	bhm_spiders_clusters_ps1dr2
# 	mwm_yso_s3
# 	mwm_tessrgb_core
# 	mwm_cb_uvex4
# 	mwm_snc_ext_main_boss
# 	bhm_spiders_agn_gaiadr2
# 	openfibertargets_nov2020_22
# 	mwm_tess_rgb_apogee
# 	bhm_csc_boss-bright
# 	mwm_bin_rv_short_mdwarf_apogee_12epoch
# 	manual_mwm_planet_tess_pc_apogee
# 	mwm_halo_vmp_xp_boss
# 	mwm_yso_pms_boss_zari18pms_single
# 	bhm_aqmes_wide3-faint
# 	ops_std_boss
# 	mwm_halo_sm
# 	openfibertargets_nov2020_31
# 	bhm_spiders_clusters_efeds_stragglers
# 	bhm_csc_apogee
# 	manual_bright_target_offsets_3
# 	ops_std_apogee
# 	mwm_monitor_m67_apogee_long
# 	mwm_dust_core_dist_apogee
# 	mwm_bin_rv_long_apogee
# 	bhm_aqmes_wide3
# 	ops_std_boss_gdr2
# 	openfibertargets_nov2020_1001b
# 	openfibertargets_nov2020_19a
# 	openfibertargets_nov2020_28c
# 	ops_sky_apogee_best
# 	manual_fps_position_stars_lco_apogee_10
# 	mwm_ob_cepheids
# 	mwm_legacy_ir2opt
# 	mwm_yso_cluster_boss_single
# 	openfibertargets_nov2020_11
# 	openfibertargets_nov2020_14
# 	mwm_halo_distant_rrl_boss_single
# 	manual_bhm_spiders_comm_lco
# 	manual_mwm_planet_sphere_apogee
# 	mwm_cb_cvcandidates_boss
# 	ops_std_boss_tic
# 	bhm_spiders_clusters-efeds-ls-redmapper
# 	mwm_astar_core_boss
# 	mwm_dust_core
# 	bhm_rm_known-spec
# 	ops_sky_apogee
# 	bhm_rm_known_spec
# 	mwm_bin_gaia_sb_apogee
# 	bhm_aqmes_med_faint
# 	manual_mwm_halo_distant_kgiant_near_boss
# 	mwm_rv_short-fps
# 	mwm_halo_local_high_boss_single
# 	mwm_magcloud_rgb_boss
# 	openfibertargets_nov2020_19c
# 	manual_mwm_planet_sophie_apogee
# 	mwm_ob_core_boss
# 	mwm_snc_250pc_apogee
# 	ops_std_boss_ps1dr2
# 	mwm_snc_100pc_apogee
# 	mwm_cb_uvex5
# 	manual_mwm_validation_hot_apogee
# 	manual_mwm_halo_mp_bbb
# 	openfibertargets_nov2020_24
# 	openfibertargets_nov2020_27
# 	manual_offset_mwmhalo_off30
# 	mwm_yso_s2-5
# 	mwm_yso_pms_apogee
# 	manual_mwm_magcloud_massive_boss
# 	mwm_legacy_ir2opt_boss
# 	mwm_halo_local_high_apogee_single
# 	mwm_cb_gaiagalex_apogee
# 	manual_mwm_halo_mp_wise_apogee
# 	ops_sky_apogee_good
# 	mwm_yso_pms_apogee_sagitta_edr3
# 	mwm_monitor_m67_apogee_short
# 	openfibertargets_nov2020_33
# 	manual_bright_targets_g13_offset_fixed_7
# 	openfibertargets_nov2020_34a
# 	manual_fps_position_stars_apogee_10
# 	bhm_aqmes_wide2_faint
# 	mwm_bin_gaia_sb_boss
# 	mwm_astar_core_boss_single
# 	manual_mwm_nsbh_boss
# 	bhm_aqmes_bonus_core
# 	ops_std_boss_lsdr10
# 	openfibertargets_nov2020_17
# 	mwm_wd_core
# 	mwm_yso_cmz_apogee
# 	mwm_rv_long_fps
# 	mwm_ob_cepheids_boss
# 	bhm_spiders_clusters-efeds-sdss-redmapper
# 	mwm_cb_gaiagalex
# 	openfibertargets_nov2020_12
# 	mwm_halo_mp_xp_apogee_single
# 	openfibertargets_nov2020_6a
# 	bhm_aqmes_wide2
# 	bhm_spiders_agn_gaiadr3
# 	mwm_bin_rv_short_subgiant_apogee
# 	mwm_yso_variable_boss_single
# 	mwm_rv_short_fps
# 	ops_sky_boss_best
# 	manual_mwm_halo_distant_kgiant
# 	manual_mwm_halo_mp_wise_boss_single
# 	manual_mwm_planet_ca_legacy_apogee
# 	mwm_tess_ob
# 	mwm_monitor_m15_apogee_short
# 	ops_std_boss_lsdr8
# 	bhm_rm_var
# 	mwm_ob_core_boss_single
# 	mwm_halo_local_low_boss_single
# 	bhm_spiders_clusters_lsdr8
# 	manual_offset_mwmhalo_off10
# 	openfibertargets_nov2020_47a
# 	manual_mwm_planet_gaia_astrometry_apogee
# 	mwm_yso_embedded_apogee_single
# 	manual_mwm_validation_rv_apogee
# 	mwm_bin_rv_short_mdwarf_apogee_18epoch
# 	manual_mwm_crosscalib_yso_apogee
# 	mwm_erosita_compact_gen
# 	bhm_spiders_agn-efeds
# 	bhm_aqmes_bonus-bright
# 	mwm_halo_bb_boss
# 	openfibertargets_nov2020_1001a
# 	mwm_halo_mp_xp_apogee
# 	openfibertargets_nov2020_30
# 	openfibertargets_nov2020_47d
# 	bhm_spiders_agn_hard
# 	manual_offset_mwmhalo_off00
# 	manual_bright_target_offsets_1_g13
# 	openfibertargets_nov2020_1000
# 	mwm_erosita_compact_boss
# 	mwm_cb_xmmom_boss
# 	mwm_cb_300pc
# 	manual_mwm_halo_distant_bhb_boss
# 	mwm_monitor_n188_apogee_short
# 	mwm_yso_nebula_apogee_single
# 	manual_mwm_planet_harps_apogee
# 	manual_mwm_tess_ob_apogee
# 	mwm_yso_s1
# 	mwm_yso_cluster_apogee_single
# 	mwm_yso_cmz
# 	mwm_cb_uvex3
# 	openfibertargets_nov2020_46
# 	mwm_bin_rv_short_mdwarf_apogee_08epoch
# 	manual_offset_mwmhalo_offb
# 	mwm_tess_2min_apogee
# 	openfibertargets_nov2020_47e
# 	manual_offset_mwmhalo_offa
# 	manual_mwm_validation_cool_boss
# 	openfibertargets_nov2020_5
# 	mwm_yso_pms_boss
# 	openfibertargets_nov2020_32
# 	ops_sky_boss_good
# 	manual_nsbh_boss
# 	mwm_halo_bb
# 	manual_bright_target_offsets_1
# 	bhm_rm_ancillary
# 	bhm_spiders_agn_ps1dr2
# 	openfibertargets_nov2020_8
# 	bhm_csc_boss
# 	mwm_snc_ext_main_apogee
# 	openfibertargets_nov2020_15
# 	mwm_yso_variable_apogee_single
# 	mwm_yso_disk_apogee
# 	manual_fps_position_stars_10
# 	mwm_cb_300pc_boss
# 	mwm_rv_short-rm
# 	bhm_aqmes_bonus-dark
# 	mwm_erosita_stars
# 	manual_mwm_planet_gpi_apogee
# 	mwm_cb_galex_vol_boss
# 	manual_mwm_planet_known_apogee
# 	manual_offset_mwmhalo_off20
# 	mwm_yso_pms_apogee_zari18pms_single
# 	mwm_erosita_compact_boss_shallow
# 	mwm_halo_distant_rrl_boss
# 	bhm_aqmes_med
# 	bhm_spiders_agn_lsdr8
# 	mwm_bin_gaia_astb_apogee
# 	bhm_rm_xrayqso
# 	manual_mwm_crosscalib_apogee
# 	bhm_rm_core
# 	mwm_cb_uvex2
# 	mwm_yso_variable_apogee
# 	manual_mwm_magcloud_symbiotic_apogee
# 	mwm_cb_cvcandidates_apogee
# 	openfibertargets_nov2020_29
# 	bhm_spiders_clusters-efeds-hsc-redmapper
# 	manual_mwm_tess_ob
# 	mwm_yso_pms_apogee_sagitta_edr3_single
# 	mwm_cb_uvex1
# 	mwm_snc_250pc_boss
# 	openfibertargets_nov2020_3
# 	manual_mwm_halo_vmp_wise_boss_single
# 	mwm_halo_nmp_xp_apogee_single
# 	ops_sky_boss
# 	bhm_aqmes_med-faint
# 	ops_std_eboss
# 	bhm_spiders_agn_efeds_stragglers
# Alternative cartons names
# 	manual_mwm_planet_known
# 	mwm_bin_openfiber
# 	mwm_magcloud_agb
# 	mwm_halo_mp_xp
# 	bhm_csc
# 	manual_mwm_planet_tess_pc
# 	manual_mwm_planet_tess_eb
# 	mwm_bin_gaia_sb
# 	mwm_ob_cepheids
# 	bhm_filler
# 	bhm_rm
# 	mwm_legacy_ir2opt
# 	mwm_galactic_core
# 	mwm_halo_local
# 	mwm_halo_openfiber
# 	ops_sky
# 	mwm_magcloud_rgb
# 	bhm_openfiber
# 	mwm_cb_swiftuvot
# 	mwm_magcloud_symbiotic
# 	mwm_cb_300pc
# 	mwm_yso_ob
# 	manual_offset_mwmhalo
# 	mwm_dust_core
# 	ops_std
# 	mwm_cb_galex
# 	mwm_bin_rv_short_rgb
# 	mwm_yso_cmz
# 	mwm_crosscalib_yso
# 	manual_mwm_planet_harps
# 	mwm_openfiber
# 	bhm_aqmes
# 	mwm_tess_rgb
# 	manual_fps_position_stars_apogee
# 	mwm_validation_hot
# 	mwm_yso_pms
# 	mwm_magcloud_massive
# 	mwm_yso_disk
# 	mwm_snc
# 	mwm_cb_cvcandidates
# 	mwm_validation_cool
# 	manual_mwm_planet_sophie
# 	mwm_halo_distant_rrl
# 	mwm_halo_bb
# 	manual_mwm_halo_mp_wise
# 	mwm_validation_openfiber
# 	mwm_snc_openfiber
# 	mwm_yso_cluster
# 	mwm_yso_variable
# 	manual_mwm_planet_sphere
# 	mwm_bin_rv_short_subgiant
# 	mwm_ob_core
# 	manual_mwm_planet_ca_legacy
# 	mwm_validation_rv
# 	manual_mwm_planet_gpi
# 	mwm_erosita_stars
# 	manual_mwm_nsbh
# 	bhm_spiders
# 	mwm_cluster_openfiber
# 	manual_mwm_halo_distant_bhb
# 	mwm_bin_rv_short
# 	mwm_crosscalib
# 	mwm_wd
# 	mwm_tess_2min
# 	mwm_yso_nebula
# 	mwm_cb_xmmom
# 	manual_mwm_halo_distant_kgiant
# 	mwm_bin_rv_short_mdwarf
# 	mwm_yso_embedded
# 	mwm_bin_vis
# 	mwm_tess_ob
# 	mwm_monitor_apogee_m67
# 	manual_mwm_planet_gaia_astrometry
# 	mwm_monitor_apogee_n188
# 	mwm_bin_gaia_astb
# 	mwm_erosita_compact
# 	mwm_monitor_apogee_m15
# 	manual_mwm_planet_transiting_bd
# 	mwm_bin_rv_long
# 	mwm_halo_sm
# Alternative programs
# 	std
# 	cb
# 	snc
# 	aqmes
# 	erosita
# 	halo
# 	tess
# 	galactic
# 	open_fiber
# 	monitor
# 	spiders
# 	nsbh
# 	csc
# 	tessrgb
# 	bin
# 	tessob
# 	rm
# 	validation
# 	yso
# 	planet
# 	commissioning
# 	dust
# 	ob
# 	wd
# 	magcloud
# 	sky
# 	legacy
# 	filler

# %% [markdown]
# ### Select by Mapper
# If you want to check which rows are in a particular mapper

# %%
# Select things assigned to MWM
mwm_mask = flags.in_mapper("mwm")
mwm_mask
# Out:
# array([ True, False,  True, ..., False,  True, False])

# %%
print(f"There are {np.sum(flags.in_mapper('mwm')):,} things assigned to MWM")
# Out:
# There are 577,505 things assigned to MWM

# %% [markdown]
# ### Select by Program
# If you want to check which rows are in a particular program

# %%
flags.in_program("mwm_wd")
# Out:
# array([False, False,  True, ..., False, False, False])

# %% [markdown]
# ### Select by name
# If you want to check which rows are in a particular carton

# %%
flags.in_carton_name("mwm_snc_250pc")
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ## I have a target, how was it targeted?
#
# If you have a CATALOGID or SDSS_ID and would like to know the targeting cartons for that source

# %%
catalogid = 27021598754184543
idx = np.where((boss_data["CATALOGID21"] == catalogid) |
               (boss_data["CATALOGID25"] == catalogid) | 
               (boss_data["CATALOGID31"] == catalogid))[0]
flag1 = TargetingFlags(boss_data["SDSS5_TARGET_FLAGS"][idx])
for label, count in flag1.count(skip_empty=True).items():
    print(f"{label}")
# Out:
# mwm_yso_s3_0.1.0
# mwm_yso_cluster_0.1.0
# mwm_yso_variable_apogee_0.5.0
# mwm_yso_variable_boss_0.5.0
# mwm_yso_cluster_apogee_0.5.0
# mwm_yso_cluster_boss_0.5.0
# mwm_yso_cluster_apogee_0.5.17
# mwm_yso_cluster_boss_0.5.17
# mwm_yso_variable_apogee_0.5.17
# mwm_yso_variable_boss_0.5.17
# mwm_yso_cluster_apogee_1.0.6
# mwm_yso_cluster_boss_1.0.6
# mwm_yso_variable_apogee_1.0.6
# mwm_yso_variable_boss_1.0.6
# mwm_yso_variable_apogee_single_1.0.33
# mwm_yso_variable_boss_single_1.0.33
# mwm_yso_cluster_apogee_single_1.0.33
# mwm_yso_cluster_boss_single_1.0.33

# %%
sdss_id = 87406300
idx = np.where(boss_data["SDSS_ID"] == sdss_id)[0]
flag1 = TargetingFlags(boss_data["SDSS5_TARGET_FLAGS"][idx])
for label, count in flag1.count(skip_empty=True).items():
    print(f"{label}")
# Out:
# mwm_yso_s3_0.1.0
# mwm_yso_cluster_0.1.0
# mwm_yso_variable_apogee_0.5.0
# mwm_yso_variable_boss_0.5.0
# mwm_yso_cluster_apogee_0.5.0
# mwm_yso_cluster_boss_0.5.0
# mwm_yso_cluster_apogee_0.5.17
# mwm_yso_cluster_boss_0.5.17
# mwm_yso_variable_apogee_0.5.17
# mwm_yso_variable_boss_0.5.17
# mwm_yso_cluster_apogee_1.0.6
# mwm_yso_cluster_boss_1.0.6
# mwm_yso_variable_apogee_1.0.6
# mwm_yso_variable_boss_1.0.6
# mwm_yso_variable_apogee_single_1.0.33
# mwm_yso_variable_boss_single_1.0.33
# mwm_yso_cluster_apogee_single_1.0.33
# mwm_yso_cluster_boss_single_1.0.33

# %% [markdown]
# ## About this notebook
#
# This notebook was created to give an example of using the `semaphore` tool with the mwmAllVisit file
#
# **Authors**: Andy Casey (andrew.casey@monash.edu), Sean Morrison
#
# **Last Update**: 2024 December 3
#
# If you use `astropy`  for published research, please cite the
# authors. Follow this link for more information about citing `astropy`:
#
# * [Citing `astropy`](https://www.astropy.org/acknowledging.html)
#
# And of course please [cite](https://sdss.org/collaboration/citing-sdss/) SDSS when you use our data.
